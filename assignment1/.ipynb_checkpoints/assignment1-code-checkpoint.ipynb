# %% [markdown]
# ## CS164 - Assignment 1
# ### Juan Castro Fernandez

# %% [markdown]
# <img src="img-ass1-cs164.png">

# %% [markdown]
# (1) Expression for the cross-sectional area of the channel A as a function of a and θ only.

# %% [markdown]
# <img src="img-ass1-cs164-2.png">

# %% [markdown]
# The area of the cross-sectional area is equal to the area of the rectangle $(EBCD)_{Area}=bh$ plus the area of the triangle $(ABE)_{Area}=\frac{xh}{2}$.
#
# But, using the defintions of sine and cosine, we get that $h=a sin(\theta)$ and $x= a cos(\theta)$. Furtheremore, we know that $W=h+b+a=3$, and so $b=3-h-a=3-asin(\theta)-a$.
#
# Therefore,
#
# $$A(a,\theta) = (3-asin(\theta)-a)(asin(\theta)) + \frac{1}{2}acos(\theta)asin(\theta) = $$
#
# $$ 3asin(\theta)-a^2sin^2(\theta)-a^2sin(\theta)+\frac{1}{2}a^2cos(\theta)sin(\theta)$$
#
# Now, the physically-realistic values for $a$ are in $[0,3]$ and for $\theta$ in $0,\frac{\pi}{2}$. This is because $a$ cannot be a negative value since it is the magnitude of the $AB$ segment, and $\theta$ has to be between $0$ and $180$ degrees because otherwise, the drainage would not be able to hold water.
#
# Given that our domain is $a \in [0,3]$ and $\theta \in [0,\pi]$, we can draw the contour plot of $A(a,\theta)$:

# %% [markdown]
# (a) Estimate the values of a and θ that maximize the area from your plot. Does
# the maximum appear to be unique over the domain of physically-realistic
# values? Justify your answer.

# %% [markdown]
# From our contour plot, it seems that our maximum is unique around $(1,1)$, which would make the value of $A$ be:

# %%
f = lambda x,y: ((x**2*np.sin(y)*np.cos(y))/2) - (x**2*np.sin(y)**2) + (3*x * np.sin(y))-(x**2*np.sin(y))
print('A(1,1) = ' +str(f(1,1)))

# %% [markdown]
# (b) Determine whether or not the negated function −A(a, θ) is coercive, justifying your answer.

# %% [markdown]
# It is coercive because, from the graph we can observe that the sublevel sets are compact

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import axes3d 

# %matplotlib notebook

fig = plt.figure(figsize=(8,6))
left, bottom, width, height = 1, 1, 1, 1
ax = fig.add_axes([left, bottom, width, height]) 

#a
x_vals = np.linspace(0, 3, 100)

#theta
y_vals = np.linspace(0, np.pi, 100)
X1, Y1 = np.meshgrid(x_vals, y_vals)

# Z = 0.5*(-2*np.sin(Y)**2+np.sin(Y)*np.cos(Y)-2*np.sin(Y))*X**2+3*np.sin(Y)*X
Z = ((X1**2*np.sin(Y1)*np.cos(Y1))/2) - (X1**2*np.sin(Y1)**2) + (3*X1 * np.sin(Y1))-(X1**2*np.sin(Y1))

cp = plt.contour(X1, Y1, Z,100,cmap='RdBu')
plt.colorbar(cp)
ax.set_title('Contour Plot of A(a,theta)')
ax.set_xlabel('a (m)')
ax.set_ylabel('theta (radians)')
plt.show()

fig = plt.figure(figsize=(11,8))
ax = fig.add_subplot(111, projection='3d')

ax.contour3D(X1,Y1,Z,200,cmap='RdBu')
ax.plot_surface(X1, Y1, Z, cmap='RdBu', rcount=100,alpha=0.5)
plt.colorbar(cp)
ax.set_title('Contour Plot of A(a,theta) in 3D')
ax.set_xlabel('a (m)')
ax.set_ylabel('theta (radians)')
ax.set_zlabel('f(a,theta)')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
left, bottom, width, height = 1, 1, 1, 1
ax = fig.add_axes([left, bottom, width, height]) 
cp = plt.contourf(X1, Y1, -Z,50,cmap='RdBu')
plt.colorbar(cp)
ax.set_title('Contour Plot of -A(a,theta)')
ax.set_xlabel('a (m)')
ax.set_ylabel('theta (radians)')
plt.show()

# %% [markdown]
# (2) Using multivariable calculus, find the exact values of a and θ that maximize the
# cross-sectional area of the channel. To accomplish this, consider b as a variable
# and use Lagrange multipliers on the area function A(a, b, θ), constraining the
# three variables by the width of the sheet - this will simplify calculations compared to maximizing A(a, θ) directly. Prove that the solution you found maximizes the area by applying appropriate tests, assuming the domain is restricted
# to physically-realistic solutions.

# %% [markdown]
# $max A(a,b,\theta) = absin(\theta)+a^2sin(\theta)cos(\theta)$
#
# subject to
#
# $W(a,b,\theta) = a+b+asin(\theta) - 3 = 0$
#
# $L(a,b,\theta,\lambda) = absin(\theta)+a^2sin(\theta)cos(\theta) - \lambda(a+b+asin(\theta) - 3)$
#
# By taking the gradient, we get the following system of equations:
#
# (i) $\frac{\partial L}{\partial a} = bsin(\theta)+acos(\theta)sin(\theta)-\lambda-\lambda sin(\theta) = 0 $
#
# (ii) $\frac{\partial L}{\partial b} = asin(\theta)-\lambda = 0 $
#
# (iii) $\frac{\partial L}{\partial \theta} = abcos(\theta)+\frac{1}{2}a^2(cos^2(\theta)-sin^2(\theta))-\lambda a cos(\theta) = 0$
#
# (iv) $\frac{\partial L}{\partial \lambda} = a+b+asin(\theta)-3 = 0$
#
# From this system of equations we obtain the following possible set of solutions (solved it using <a href="https://www.wolframalpha.com/input/?i=b*sin%28x%29%2Ba*cos%28x%29sin%28x%29-c-c*sin%28x%29+%3D+0%2C+a*sin%28x%29+-+c+%3D+0%2C+a*b*cos%28x%29+%2B%281%2F2%29*a%5E2%28cos%28x%29%5E2-sin%28x%29%5E2%29-ca*cos%28x%29%3D0%2C+a%2Bb%2Ba*sin%28x%29-3%3D0">Wolfram Alpha</a>):
#
# 1. $a=0, \ b=3, \ \lambda=0, \ \theta=\pi n, \ \ \ n \in \mathbb{Z}$
# 2. $a=2, \ b=1, \ \lambda=0, \ \theta=2\pi n+\pi, \ \ \ n \in \mathbb{Z}$
# 3. $a=6, \ b=-3, \ \lambda=0, \ \theta=2\pi n, \ \ \ n \in \mathbb{Z}$
# 4. $a=4\sqrt{3}-6, \ b=3-\sqrt{3}, \ \lambda=6-3\sqrt{3}, \ \theta=2\pi n+\frac{\pi}{3}, \ \ \ n \in \mathbb{Z}$
# 5. $a=-6-4\sqrt{3}, \ b=3+\sqrt{3}, \ \lambda=6+3\sqrt{3}, \ \theta=2\pi n-\frac{\pi}{3}, \ \ \ n \in \mathbb{Z}$
#
# From which we can discard the third because $a$ has to be $\leq3$, and the last one because $a$ cannot be negative.
#
# The values of $f$ that correspond to remaining solutions are:
#
# 1. $A(0,\pi) = 0$
# 2. $A(2,\pi) = 0$
# 3. $A(4\sqrt{3}-6,\frac{\pi}{3}) = \frac{18-9\sqrt{3}}{2} \approx 1.20577 $
#
# Where the third is the maximum.

# %% [markdown]
# (3) Considering once again the function A(a, θ), implement gradient ascent with a
# line search (exact or backtracking) in Python and from the initial state (1.5, 0),
# verify that you reach the same optimal solution. Produce a table of steps showing how the algorithm converges, and plot the convergence over the contour
# plot of A(·, ·)

# %% [markdown]
# ### Gradient Ascent with backtracking line search

# %%
import numpy as np

#x=a, y=theta
def A(x,y):
    return ((x**2*np.sin(y)*np.cos(y))/2) - (x**2*np.sin(y)**2) + (3*x * np.sin(y))-(x**2*np.sin(y))

def gradA(x,y):
    partial_x= np.sin(y)*(-2*x*np.sin(y)+x*np.cos(y)-2*x+3)
    partial_y= (1/2)*x*(-x*np.sin(y)**2+x*np.cos(y)**2-2*np.cos(y)*(2*x*np.sin(y)+x-3))
    return np.array([partial_x, partial_y])

def backtracking(alpha,beta,x,grad,s_init=1):
    v = grad/np.linalg.norm(grad)
    s = s_init
    d = np.dot(grad.T,v)
    while A(x[0]+s*v[0],x[1]+s*v[1]) < A(x[0],x[1])+s*alpha*d:
        s*=beta
    return s

def gradient_ascent(X0,line_search =  True,alpha=0.5,beta=0.5):
    X_k0 = [X0[0]]
    X_k1 = [X0[1]]
    X = X0
    X_old = X+1
    k = 0
    if line_search:
        while np.linalg.norm(X-X_old) > 1e-6:
            step = backtracking(alpha,beta,X,gradA(X[0],X[1]),1)
            X_new = X + step*gradA(X[0], X[1])/np.linalg.norm(gradA(X[0], X[1]))
            X_old = X
            X = X_new
            X_k0.append(X[0])
            X_k1.append(X[1])
            k+=1
    else:
        step = 0.01
        while np.linalg.norm(X-X_old) > 1e-6:
            X_new = X + step*gradA(X[0], X[1])
            X_old = X
            X = X_new
            X_k0.append(X[0])
            X_k1.append(X[1])
            k+=1
    return (X,X_k0,X_k1)

def plot2d(X_inits,line_search=True):
    fig = plt.figure(figsize=(10,7))
    ax = fig.add_axes([1, 1, 1, 1]) 
    cp = plt.contour(X1, Y1, Z,100,cmap='RdBu')
    plt.colorbar(cp)
    for X0 in X_inits:
        R = gradient_ascent(X0,line_search=line_search)
        X_k0, X_k1 = R[1],R[2]
        k = len(X_k0) 
        plt.plot(X_k0,X_k1, label = 'X0 = {}, converged in {} steps'.format(X0,k))
        if not line_search:
            s=5
        else:
            s=30
        plt.scatter(X_k0,X_k1,s=s)    
    plt.legend()
    if line_search:
        title = 'Gradient Ascent of A(a,theta) with backtracking line search'
    else:
        title = 'Gradient Ascent of A(a,theta) without line search'
    ax.set_title(title)
    ax.set_xlabel('a (m)')
    ax.set_ylabel('theta (radians)')
    plt.show()
    if X0[0]==1.5 and X0[1]==0:
        print('Gradient Ascent converged in {} steps'.format(k))

def plot3d(X_inits,line_search=True):
    fig = plt.figure(figsize=(10,7))
    ax = fig.add_subplot(111, projection='3d')
    ax.contour3D(X1,Y1,Z,80,cmap='RdBu',alpha=0.6)
    ax.plot_surface(X1, Y1, Z, cmap='RdBu', rcount=100,alpha=0.5)
    for X0 in X_inits:
        R = gradient_ascent(X0,line_search=line_search)
        X_k0, X_k1 = R[1],R[2]
        k = len(X_k0)
        ax.plot(X_k0,X_k1,[A(X_k0[i],X_k1[i]) for i in range(len(X_k0))],linewidth=2,label = 'X0 = {}, converged in {} steps'.format(X0,k))
    if line_search:
        title = 'Gradient Ascent of A(a,theta) with backtracking line search'
    else:
        title = 'Gradient Ascent of A(a,theta) without line search'
    ax.set_title(title)
    plt.legend()
    plt.colorbar(cp)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.show()

# %%
# %matplotlib notebook
plot3d(Xinits,line_search=True)

# %%
Xinits = [np.array([1.5,0]),np.array([2.5,1]),np.array([0.2,2]),np.array([1.8,2.5]),np.array([2,2])]
plot2d(Xinits,line_search=True)

# %%
import pandas as pd

X0=np.array([1.5,0])
R = gradient_ascent(X0,line_search=True)
X_k0, X_k1 = R[1],R[2]
F = [A(X_k0[i],X_k1[i]) for i in range(len(X_k0))]
DF = pd.DataFrame(data = {'a':X_k0,'theta':X_k1,'A(a,theta)':F})
t = list(range(5))+list(range(-10,0))
DF.iloc[t,:]

# %%
R = gradient_ascent(X0,line_search=False)
X_k0, X_k1 = R[1],R[2]
F = [A(X_k0[i],X_k1[i]) for i in range(len(X_k0))]
DF = pd.DataFrame(data = {'a':X_k0,'theta':X_k1,'A(a,theta)':F})
t = list(range(5))+list(range(-10,0))
DF.iloc[t,:]
